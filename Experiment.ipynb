# %% [markdown]
# ### KEplerGLで遊ぶ

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df2 = Kepler

# %% [markdown]
# ### xmlをパース

# %%
import  xml.etree.ElementTree as ET
from bs4 import BeautifulSoup

# %%
with open("data/S05-b-10_SYUTO/S05-b-10_SYUTO-1.xml", encoding="shift_jis") as file:
    temp = file.read()

tree = ElementTree.fromstring(temp)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-ad6dc1f71daf> in <module>
#       1 with open("data/S05-b-10_SYUTO/S05-b-10_SYUTO-1.xml", encoding="shift_jis") as file:
# ----> 2     temp = file.read()
#       3
#       4 tree = ElementTree.fromstring(temp)
#
# UnicodeDecodeError: 'shift_jis' codec can't decode byte 0xef in position 0: illegal multibyte sequence

# %%
temp = ET.parse("data/S05-b-10_SYUTO/S05-b-10_SYUTO-1.xml")
head = temp.getroot()

# %%
head.tag
# Out:
# '{http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}GI'

# %%
with open('data/S05-b-10_SYUTO/S05-b-10_SYUTO-1.xml') as file:
    read = file.read()
soup = BeautifulSoup(read, "lxml-xml")
position = soup.find_all("posList")
position = str(position)
position_split = position.split('\n')
'''
with open('sinsui_tokyo_xmldata.csv', 'w', encoding='CP932', newline="") as file:  # sumodata{}.csvに追記
    writer = csv.writer(file)
    writer.writerows([position_split])
'''
print(position_split)
# Out:
# ['[]']

# %%
temp = ET.parse("data/S05-b-10_SYUTO/S05-b-10_SYUTO-1.xml")
head = temp.getroot()
#print(ET.tostring(head).decode())
# Out:
# <class 'xml.etree.ElementTree.ElementTree'>

# %%
temp = ET.iterparse("data/S05-b-10_SYUTO/S05-b-10_SYUTO-1.xml")
for i, j in temp:
    print(type(j))
    head = j.getroot()
    print(ET.tostring(head).decode())
# Out:
# <class 'xml.etree.ElementTree.Element'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-653362ba42a6> in <module>
#       2 for i, j in temp:
#       3     print(type(j))
# ----> 4     head = j.getroot()
#       5     print(ET.tostring(head).decode())
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'getroot'

# %% [markdown]
# ### 自主管理歩道

# %%
df7 = gpd.read_file('data/road/7choume(3857).shp')
df8 = gpd.read_file('data/road/8choume(3857).shp')
df9 = gpd.read_file('data/road/9choume(3857).shp')

# %%
# Out:
# LINESTRING Z (139.65395 35.790455 0, 139.653652 35.790514 0)
